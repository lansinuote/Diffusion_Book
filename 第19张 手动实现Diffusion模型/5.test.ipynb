# %%
#第19章/初始化工具类
from diffusers import DiffusionPipeline
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'

pipeline = DiffusionPipeline.from_pretrained(
    'lansinuote/diffsion_from_scratch.params', safety_checker=None)

scheduler = pipeline.scheduler
tokenizer = pipeline.tokenizer

del pipeline

device, scheduler, tokenizer
# Out:
# /root/anaconda3/envs/pt39/lib/python3.9/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# ('cuda',
#  PNDMScheduler {
#    "_class_name": "PNDMScheduler",
#    "_diffusers_version": "0.15.1",
#    "beta_end": 0.012,
#    "beta_schedule": "scaled_linear",
#    "beta_start": 0.00085,
#    "clip_sample": false,
#    "num_train_timesteps": 1000,
#    "prediction_type": "epsilon",
#    "set_alpha_to_one": false,
#    "skip_prk_steps": true,
#    "steps_offset": 1,
#    "trained_betas": null
#  },
#  CLIPTokenizer(name_or_path='/root/.cache/huggingface/hub/models--lansinuote--diffsion_from_scratch.params/snapshots/310d9345e14b3b625635041dd573676c008d83ea/tokenizer', vocab_size=49408, model_max_length=77, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'bos_token': AddedToken("<|startoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'eos_token': AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'unk_token': AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'pad_token': '<|endoftext|>'}))

# %%
#第19章/加载模型
# %run 1.encoder.ipynb
# %run 2.vae.ipynb
# %run 3.unet.ipynb

encoder.to(device)
vae.to(device)
unet.to(device)

encoder.eval()
vae.eval()
unet.eval()
# Out:
# UNet(
#   (in_vae): Conv2d(4, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (in_time): Sequential(
#     (0): Linear(in_features=320, out_features=1280, bias=True)
#     (1): SiLU()
#     (2): Linear(in_features=1280, out_features=1280, bias=True)
#   )
#   (down_block0): DownBlock(
#     (tf0): Transformer(
#       (norm_in): GroupNorm(32, 320, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=320, out_features=320, bias=False)
#         (k): Linear(in_features=320, out_features=320, bias=False)
#         (v): Linear(in_features=320, out_features=320, bias=False)
#         (out): Linear(in_features=320, out_features=320, bias=True)
#       )
#       (norm_atten1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=320, out_features=320, bias=False)
#         (k): Linear(in_features=768, out_features=320, bias=False)
#         (v): Linear(in_features=768, out_features=320, bias=False)
#         (out): Linear(in_features=320, out_features=320, bias=True)
#       )
#       (norm_act): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=320, out_features=2560, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=1280, out_features=320, bias=True)
#       (cnn_out): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (res0): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=320, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(320, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 320, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 320, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (tf1): Transformer(
#       (norm_in): GroupNorm(32, 320, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=320, out_features=320, bias=False)
#         (k): Linear(in_features=320, out_features=320, bias=False)
#         (v): Linear(in_features=320, out_features=320, bias=False)
#         (out): Linear(in_features=320, out_features=320, bias=True)
#       )
#       (norm_atten1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=320, out_features=320, bias=False)
#         (k): Linear(in_features=768, out_features=320, bias=False)
#         (v): Linear(in_features=768, out_features=320, bias=False)
#         (out): Linear(in_features=320, out_features=320, bias=True)
#       )
#       (norm_act): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=320, out_features=2560, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=1280, out_features=320, bias=True)
#       (cnn_out): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (res1): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=320, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(320, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 320, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 320, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (out): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   )
#   (down_block1): DownBlock(
#     (tf0): Transformer(
#       (norm_in): GroupNorm(32, 640, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=640, out_features=640, bias=False)
#         (k): Linear(in_features=640, out_features=640, bias=False)
#         (v): Linear(in_features=640, out_features=640, bias=False)
#         (out): Linear(in_features=640, out_features=640, bias=True)
#       )
#       (norm_atten1): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=640, out_features=640, bias=False)
#         (k): Linear(in_features=768, out_features=640, bias=False)
#         (v): Linear(in_features=768, out_features=640, bias=False)
#         (out): Linear(in_features=640, out_features=640, bias=True)
#       )
#       (norm_act): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=640, out_features=5120, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=2560, out_features=640, bias=True)
#       (cnn_out): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (res0): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=640, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(640, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 320, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(320, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 640, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (res): Conv2d(320, 640, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (tf1): Transformer(
#       (norm_in): GroupNorm(32, 640, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=640, out_features=640, bias=False)
#         (k): Linear(in_features=640, out_features=640, bias=False)
#         (v): Linear(in_features=640, out_features=640, bias=False)
#         (out): Linear(in_features=640, out_features=640, bias=True)
#       )
#       (norm_atten1): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=640, out_features=640, bias=False)
#         (k): Linear(in_features=768, out_features=640, bias=False)
#         (v): Linear(in_features=768, out_features=640, bias=False)
#         (out): Linear(in_features=640, out_features=640, bias=True)
#       )
#       (norm_act): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=640, out_features=5120, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=2560, out_features=640, bias=True)
#       (cnn_out): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (res1): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=640, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(640, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 640, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 640, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (out): Conv2d(640, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   )
#   (down_block2): DownBlock(
#     (tf0): Transformer(
#       (norm_in): GroupNorm(32, 1280, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=1280, out_features=1280, bias=False)
#         (k): Linear(in_features=1280, out_features=1280, bias=False)
#         (v): Linear(in_features=1280, out_features=1280, bias=False)
#         (out): Linear(in_features=1280, out_features=1280, bias=True)
#       )
#       (norm_atten1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=1280, out_features=1280, bias=False)
#         (k): Linear(in_features=768, out_features=1280, bias=False)
#         (v): Linear(in_features=768, out_features=1280, bias=False)
#         (out): Linear(in_features=1280, out_features=1280, bias=True)
#       )
#       (norm_act): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=1280, out_features=10240, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=5120, out_features=1280, bias=True)
#       (cnn_out): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (res0): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=1280, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(1280, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 640, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(640, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (res): Conv2d(640, 1280, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (tf1): Transformer(
#       (norm_in): GroupNorm(32, 1280, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=1280, out_features=1280, bias=False)
#         (k): Linear(in_features=1280, out_features=1280, bias=False)
#         (v): Linear(in_features=1280, out_features=1280, bias=False)
#         (out): Linear(in_features=1280, out_features=1280, bias=True)
#       )
#       (norm_atten1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=1280, out_features=1280, bias=False)
#         (k): Linear(in_features=768, out_features=1280, bias=False)
#         (v): Linear(in_features=768, out_features=1280, bias=False)
#         (out): Linear(in_features=1280, out_features=1280, bias=True)
#       )
#       (norm_act): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=1280, out_features=10240, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=5120, out_features=1280, bias=True)
#       (cnn_out): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (res1): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=1280, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(1280, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (out): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   )
#   (down_res0): Resnet(
#     (time): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=1280, out_features=1280, bias=True)
#       (2): Unflatten(dim=1, unflattened_size=(1280, 1, 1))
#     )
#     (s0): Sequential(
#       (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (s1): Sequential(
#       (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (down_res1): Resnet(
#     (time): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=1280, out_features=1280, bias=True)
#       (2): Unflatten(dim=1, unflattened_size=(1280, 1, 1))
#     )
#     (s0): Sequential(
#       (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (s1): Sequential(
#       (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (mid_res0): Resnet(
#     (time): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=1280, out_features=1280, bias=True)
#       (2): Unflatten(dim=1, unflattened_size=(1280, 1, 1))
#     )
#     (s0): Sequential(
#       (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (s1): Sequential(
#       (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (mid_tf): Transformer(
#     (norm_in): GroupNorm(32, 1280, eps=1e-06, affine=True)
#     (cnn_in): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#     (norm_atten0): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#     (atten1): CrossAttention(
#       (q): Linear(in_features=1280, out_features=1280, bias=False)
#       (k): Linear(in_features=1280, out_features=1280, bias=False)
#       (v): Linear(in_features=1280, out_features=1280, bias=False)
#       (out): Linear(in_features=1280, out_features=1280, bias=True)
#     )
#     (norm_atten1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#     (atten2): CrossAttention(
#       (q): Linear(in_features=1280, out_features=1280, bias=False)
#       (k): Linear(in_features=768, out_features=1280, bias=False)
#       (v): Linear(in_features=768, out_features=1280, bias=False)
#       (out): Linear(in_features=1280, out_features=1280, bias=True)
#     )
#     (norm_act): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#     (fc0): Linear(in_features=1280, out_features=10240, bias=True)
#     (act): GELU(approximate=none)
#     (fc1): Linear(in_features=5120, out_features=1280, bias=True)
#     (cnn_out): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (mid_res1): Resnet(
#     (time): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=1280, out_features=1280, bias=True)
#       (2): Unflatten(dim=1, unflattened_size=(1280, 1, 1))
#     )
#     (s0): Sequential(
#       (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (s1): Sequential(
#       (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (up_res0): Resnet(
#     (time): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=1280, out_features=1280, bias=True)
#       (2): Unflatten(dim=1, unflattened_size=(1280, 1, 1))
#     )
#     (s0): Sequential(
#       (0): GroupNorm(32, 2560, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(2560, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (s1): Sequential(
#       (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (res): Conv2d(2560, 1280, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (up_res1): Resnet(
#     (time): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=1280, out_features=1280, bias=True)
#       (2): Unflatten(dim=1, unflattened_size=(1280, 1, 1))
#     )
#     (s0): Sequential(
#       (0): GroupNorm(32, 2560, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(2560, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (s1): Sequential(
#       (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (res): Conv2d(2560, 1280, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (up_res2): Resnet(
#     (time): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=1280, out_features=1280, bias=True)
#       (2): Unflatten(dim=1, unflattened_size=(1280, 1, 1))
#     )
#     (s0): Sequential(
#       (0): GroupNorm(32, 2560, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(2560, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (s1): Sequential(
#       (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (res): Conv2d(2560, 1280, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (up_in): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (up_block0): UpBlock(
#     (res0): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=1280, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(1280, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 2560, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(2560, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (res): Conv2d(2560, 1280, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (res1): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=1280, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(1280, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 2560, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(2560, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (res): Conv2d(2560, 1280, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (res2): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=1280, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(1280, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 1920, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(1920, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (res): Conv2d(1920, 1280, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (tf0): Transformer(
#       (norm_in): GroupNorm(32, 1280, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=1280, out_features=1280, bias=False)
#         (k): Linear(in_features=1280, out_features=1280, bias=False)
#         (v): Linear(in_features=1280, out_features=1280, bias=False)
#         (out): Linear(in_features=1280, out_features=1280, bias=True)
#       )
#       (norm_atten1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=1280, out_features=1280, bias=False)
#         (k): Linear(in_features=768, out_features=1280, bias=False)
#         (v): Linear(in_features=768, out_features=1280, bias=False)
#         (out): Linear(in_features=1280, out_features=1280, bias=True)
#       )
#       (norm_act): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=1280, out_features=10240, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=5120, out_features=1280, bias=True)
#       (cnn_out): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (tf1): Transformer(
#       (norm_in): GroupNorm(32, 1280, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=1280, out_features=1280, bias=False)
#         (k): Linear(in_features=1280, out_features=1280, bias=False)
#         (v): Linear(in_features=1280, out_features=1280, bias=False)
#         (out): Linear(in_features=1280, out_features=1280, bias=True)
#       )
#       (norm_atten1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=1280, out_features=1280, bias=False)
#         (k): Linear(in_features=768, out_features=1280, bias=False)
#         (v): Linear(in_features=768, out_features=1280, bias=False)
#         (out): Linear(in_features=1280, out_features=1280, bias=True)
#       )
#       (norm_act): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=1280, out_features=10240, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=5120, out_features=1280, bias=True)
#       (cnn_out): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (tf2): Transformer(
#       (norm_in): GroupNorm(32, 1280, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=1280, out_features=1280, bias=False)
#         (k): Linear(in_features=1280, out_features=1280, bias=False)
#         (v): Linear(in_features=1280, out_features=1280, bias=False)
#         (out): Linear(in_features=1280, out_features=1280, bias=True)
#       )
#       (norm_atten1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=1280, out_features=1280, bias=False)
#         (k): Linear(in_features=768, out_features=1280, bias=False)
#         (v): Linear(in_features=768, out_features=1280, bias=False)
#         (out): Linear(in_features=1280, out_features=1280, bias=True)
#       )
#       (norm_act): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=1280, out_features=10240, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=5120, out_features=1280, bias=True)
#       (cnn_out): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (out): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (up_block1): UpBlock(
#     (res0): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=640, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(640, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 1920, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(1920, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 640, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (res): Conv2d(1920, 640, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (res1): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=640, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(640, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 1280, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(1280, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 640, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (res): Conv2d(1280, 640, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (res2): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=640, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(640, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 960, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(960, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 640, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (res): Conv2d(960, 640, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (tf0): Transformer(
#       (norm_in): GroupNorm(32, 640, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=640, out_features=640, bias=False)
#         (k): Linear(in_features=640, out_features=640, bias=False)
#         (v): Linear(in_features=640, out_features=640, bias=False)
#         (out): Linear(in_features=640, out_features=640, bias=True)
#       )
#       (norm_atten1): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=640, out_features=640, bias=False)
#         (k): Linear(in_features=768, out_features=640, bias=False)
#         (v): Linear(in_features=768, out_features=640, bias=False)
#         (out): Linear(in_features=640, out_features=640, bias=True)
#       )
#       (norm_act): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=640, out_features=5120, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=2560, out_features=640, bias=True)
#       (cnn_out): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (tf1): Transformer(
#       (norm_in): GroupNorm(32, 640, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=640, out_features=640, bias=False)
#         (k): Linear(in_features=640, out_features=640, bias=False)
#         (v): Linear(in_features=640, out_features=640, bias=False)
#         (out): Linear(in_features=640, out_features=640, bias=True)
#       )
#       (norm_atten1): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=640, out_features=640, bias=False)
#         (k): Linear(in_features=768, out_features=640, bias=False)
#         (v): Linear(in_features=768, out_features=640, bias=False)
#         (out): Linear(in_features=640, out_features=640, bias=True)
#       )
#       (norm_act): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=640, out_features=5120, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=2560, out_features=640, bias=True)
#       (cnn_out): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (tf2): Transformer(
#       (norm_in): GroupNorm(32, 640, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=640, out_features=640, bias=False)
#         (k): Linear(in_features=640, out_features=640, bias=False)
#         (v): Linear(in_features=640, out_features=640, bias=False)
#         (out): Linear(in_features=640, out_features=640, bias=True)
#       )
#       (norm_atten1): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=640, out_features=640, bias=False)
#         (k): Linear(in_features=768, out_features=640, bias=False)
#         (v): Linear(in_features=768, out_features=640, bias=False)
#         (out): Linear(in_features=640, out_features=640, bias=True)
#       )
#       (norm_act): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=640, out_features=5120, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=2560, out_features=640, bias=True)
#       (cnn_out): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (out): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (up_block2): UpBlock(
#     (res0): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=320, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(320, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 960, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(960, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 320, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (res): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (res1): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=320, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(320, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 640, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(640, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 320, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (res): Conv2d(640, 320, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (res2): Resnet(
#       (time): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=1280, out_features=320, bias=True)
#         (2): Unflatten(dim=1, unflattened_size=(320, 1, 1))
#       )
#       (s0): Sequential(
#         (0): GroupNorm(32, 640, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(640, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (s1): Sequential(
#         (0): GroupNorm(32, 320, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (res): Conv2d(640, 320, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (tf0): Transformer(
#       (norm_in): GroupNorm(32, 320, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=320, out_features=320, bias=False)
#         (k): Linear(in_features=320, out_features=320, bias=False)
#         (v): Linear(in_features=320, out_features=320, bias=False)
#         (out): Linear(in_features=320, out_features=320, bias=True)
#       )
#       (norm_atten1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=320, out_features=320, bias=False)
#         (k): Linear(in_features=768, out_features=320, bias=False)
#         (v): Linear(in_features=768, out_features=320, bias=False)
#         (out): Linear(in_features=320, out_features=320, bias=True)
#       )
#       (norm_act): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=320, out_features=2560, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=1280, out_features=320, bias=True)
#       (cnn_out): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (tf1): Transformer(
#       (norm_in): GroupNorm(32, 320, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=320, out_features=320, bias=False)
#         (k): Linear(in_features=320, out_features=320, bias=False)
#         (v): Linear(in_features=320, out_features=320, bias=False)
#         (out): Linear(in_features=320, out_features=320, bias=True)
#       )
#       (norm_atten1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=320, out_features=320, bias=False)
#         (k): Linear(in_features=768, out_features=320, bias=False)
#         (v): Linear(in_features=768, out_features=320, bias=False)
#         (out): Linear(in_features=320, out_features=320, bias=True)
#       )
#       (norm_act): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=320, out_features=2560, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=1280, out_features=320, bias=True)
#       (cnn_out): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (tf2): Transformer(
#       (norm_in): GroupNorm(32, 320, eps=1e-06, affine=True)
#       (cnn_in): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#       (norm_atten0): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (atten1): CrossAttention(
#         (q): Linear(in_features=320, out_features=320, bias=False)
#         (k): Linear(in_features=320, out_features=320, bias=False)
#         (v): Linear(in_features=320, out_features=320, bias=False)
#         (out): Linear(in_features=320, out_features=320, bias=True)
#       )
#       (norm_atten1): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (atten2): CrossAttention(
#         (q): Linear(in_features=320, out_features=320, bias=False)
#         (k): Linear(in_features=768, out_features=320, bias=False)
#         (v): Linear(in_features=768, out_features=320, bias=False)
#         (out): Linear(in_features=320, out_features=320, bias=True)
#       )
#       (norm_act): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       (fc0): Linear(in_features=320, out_features=2560, bias=True)
#       (act): GELU(approximate=none)
#       (fc1): Linear(in_features=1280, out_features=320, bias=True)
#       (cnn_out): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (out): Sequential(
#     (0): GroupNorm(32, 320, eps=1e-05, affine=True)
#     (1): SiLU()
#     (2): Conv2d(320, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
#第19章/定义生成函数
@torch.no_grad()
def generate(text):
    #词编码
    #[1, 77]
    pos = tokenizer(text,
                    padding='max_length',
                    max_length=77,
                    truncation=True,
                    return_tensors='pt').input_ids.to(device)
    neg = tokenizer('',
                    padding='max_length',
                    max_length=77,
                    truncation=True,
                    return_tensors='pt').input_ids.to(device)

    #[1, 77, 768]
    pos = encoder(pos)
    neg = encoder(neg)

    #[1+1, 77, 768] -> [2, 77, 768]
    out_encoder = torch.cat((neg, pos), dim=0)

    #vae的压缩图,从随机噪声开始
    out_vae = torch.randn(1, 4, 64, 64, device=device)

    #生成50个时间步,一般是从980-0
    scheduler.set_timesteps(50, device=device)
    for time in scheduler.timesteps:

        #往图中加噪音
        #[1+1, 4, 64, 64] -> [2, 4, 64, 64]
        noise = torch.cat((out_vae, out_vae), dim=0)
        noise = scheduler.scale_model_input(noise, time)

        #计算噪音
        #[2, 4, 64, 64],[2, 77, 768],scala -> [2, 4, 64, 64]
        pred_noise = unet(out_vae=noise, out_encoder=out_encoder, time=time)

        #从正例图中减去反例图
        #[2, 4, 64, 64] -> [1, 4, 64, 64]
        pred_noise = pred_noise[0] + 7.5 * (pred_noise[1] - pred_noise[0])

        #重新添加噪音,以进行下一步计算
        #[1, 4, 64, 64]
        out_vae = scheduler.step(pred_noise, time, out_vae).prev_sample

    #从压缩图恢复成图片
    out_vae = 1 / 0.18215 * out_vae
    #[1, 4, 64, 64] -> [1, 3, 512, 512]
    image = vae.decoder(out_vae)

    #转换成图片数据
    image = image.cpu()
    image = (image + 1) / 2
    image = image.clamp(0, 1)
    image = image.permute(0, 2, 3, 1)
    return image.numpy()[0]


generate('a drawing of a star with a jewel in the center').shape
# Out:
# (512, 512, 3)

# %%
#第19章/定义测试函数
from matplotlib import pyplot as plt
# %matplotlib inline


def show():
    texts = [
        'a pixel art character with square orange glasses, a whale-shaped head and a teal-colored body on a warm background',
        'a pixel art character with square green and blue glasses, a hanger-shaped head and a red-colored body on a warm background',
        'a pixel art character with square black sunglasses, a wallsafe-shaped head and a purple-colored body on a cool background',
        'a pixel art character with square green and blue glasses, a mushroom-shaped head and a bluegrey-colored body on a cool background',
        'a pixel art character with square pink and red glasses, a chipboard-shaped head and a blue-colored body on a cool background',
        'a pixel art character with square pink and red glasses, a spaghetti-shaped head and a darkpink-colored body on a cool background',
    ]

    images = [generate(i) for i in texts]

    plt.figure(figsize=(20, 10))
    for i in range(6):
        plt.subplot(2, 3, i + 1)
        plt.imshow(images[i])
        plt.axis('off')

    plt.show()


show()

# %%
#第19章/测试本地训练的模型
unet = torch.load('save/unet.model')

unet.eval().to(device)

show()

# %%
#第19章/在线加载笔者训练好的模型并测试
from transformers import PreTrainedModel, PretrainedConfig


#包装类
class Model(PreTrainedModel):
    config_class = PretrainedConfig

    def __init__(self, config):
        super().__init__(config)
        self.unet = unet.to('cpu')


#加载训练好的模型
while True:
    try:
        unet = Model.from_pretrained(
            'lansinuote/diffsion_from_scratch.unet.book').unet
        break
    except:
        pass

unet.eval().to(device)

show()
